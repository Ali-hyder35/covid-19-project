# %%
import pandas as pd

# %%
df = pd.read_csv('COVID-19-geographic-disbtribution-worldwide.csv')

# %%
df.head(55721)
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      15/11/2020   15     11  2020    205      12             Afghanistan
# 1      14/11/2020   14     11  2020     66      10             Afghanistan
# 2      13/11/2020   13     11  2020    360      14             Afghanistan
# 3      12/11/2020   12     11  2020    146       4             Afghanistan
# 4      11/11/2020   11     11  2020      0       0             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 55716  26/03/2020   26      3  2020      1       0                Zimbabwe
# 55717  25/03/2020   25      3  2020      0       0                Zimbabwe
# 55718  24/03/2020   24      3  2020      0       1                Zimbabwe
# 55719  23/03/2020   23      3  2020      0       0                Zimbabwe
# 55720  22/03/2020   22      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %%
df.dropna(axis=0,how='any',inplace = True)

# %%
df.fillna('Cumulative_number_for_14_days_of_COVID-19_cases_per_100000',inplace = True)

# %%
df.rename(columns={'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000':'Cumulative_number'},inplace=True)

# %%
df.set_index('Cumulative_number',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 0               4.571293  15/11/2020   15     11  2020    205      12
# 1               4.232191  14/11/2020   14     11  2020     66      10
# 2               4.471402  13/11/2020   13     11  2020    360      14
# 3               3.848403  12/11/2020   12     11  2020    146       4
# 4               3.464614  11/11/2020   11     11  2020      0       0
# ...                  ...         ...  ...    ...   ...    ...     ...
# 52642           0.047796  07/04/2020    7      4  2020      0       0
# 52643           0.047796  06/04/2020    6      4  2020      0       0
# 52644           0.047796  05/04/2020    5      4  2020      0       0
# 52645           0.054624  04/04/2020    4      4  2020      1       0
# 52646           0.054624  03/04/2020    3      4  2020      0       0
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# ...

# %%
df['Cumulative_number']
# Out:
# 0        4.571293
# 1        4.232191
# 2        4.471402
# 3        3.848403
# 4        3.464614
#            ...
# 52642    0.047796
# 52643    0.047796
# 52644    0.047796
# 52645    0.054624
# 52646    0.054624
# Name: Cumulative_number, Length: 52647, dtype: float64

# %%
df[['Cumulative_number','dateRep','day','month','year','cases','deaths','countriesAndTerritories','geoId','countryterritoryCode','popData2019','continentExp']]
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 0               4.571293  15/11/2020   15     11  2020    205      12
# 1               4.232191  14/11/2020   14     11  2020     66      10
# 2               4.471402  13/11/2020   13     11  2020    360      14
# 3               3.848403  12/11/2020   12     11  2020    146       4
# 4               3.464614  11/11/2020   11     11  2020      0       0
# ...                  ...         ...  ...    ...   ...    ...     ...
# 52642           0.047796  07/04/2020    7      4  2020      0       0
# 52643           0.047796  06/04/2020    6      4  2020      0       0
# 52644           0.047796  05/04/2020    5      4  2020      0       0
# 52645           0.054624  04/04/2020    4      4  2020      1       0
# 52646           0.054624  03/04/2020    3      4  2020      0       0
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# ...

# %%
len('Cumulative_number')
# Out:
# 17

# %%
df.columns
# Out:
# Index(['Cumulative_number', 'dateRep', 'day', 'month', 'year', 'cases',
#        'deaths', 'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp'],
#       dtype='object')

# %%
df.shape
# Out:
# (52647, 12)

# %%
df.head(52646)
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 0               4.571293  15/11/2020   15     11  2020    205      12
# 1               4.232191  14/11/2020   14     11  2020     66      10
# 2               4.471402  13/11/2020   13     11  2020    360      14
# 3               3.848403  12/11/2020   12     11  2020    146       4
# 4               3.464614  11/11/2020   11     11  2020      0       0
# ...                  ...         ...  ...    ...   ...    ...     ...
# 52641           0.054624  08/04/2020    8      4  2020      1       0
# 52642           0.047796  07/04/2020    7      4  2020      0       0
# 52643           0.047796  06/04/2020    6      4  2020      0       0
# 52644           0.047796  05/04/2020    5      4  2020      0       0
# 52645           0.054624  04/04/2020    4      4  2020      1       0
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# ...

# %%
df.tail(52000)
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 647            19.241376  28/07/2020   28      7  2020    616       8
# 648            18.958005  27/07/2020   27      7  2020    593       9
# 649            18.702506  26/07/2020   26      7  2020    605      10
# 650            18.388939  25/07/2020   25      7  2020    675      12
# 651            17.829165  24/07/2020   24      7  2020    612      13
# ...                  ...         ...  ...    ...   ...    ...     ...
# 52642           0.047796  07/04/2020    7      4  2020      0       0
# 52643           0.047796  06/04/2020    6      4  2020      0       0
# 52644           0.047796  05/04/2020    5      4  2020      0       0
# 52645           0.054624  04/04/2020    4      4  2020      1       0
# 52646           0.054624  03/04/2020    3      4  2020      0       0
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# ...

# %%
df[5:3:1]
# Out:
# Empty DataFrame
# Columns: [Cumulative_number, dateRep, day, month, year, cases, deaths, countriesAndTerritories, geoId, countryterritoryCode, popData2019, continentExp]
# Index: []

# %%
df.loc[5:9,'Cumulative_number':'countriesAndTerritories']
# Out:
#    Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 5           3.761656  10/11/2020   10     11  2020    224      12
# 6           3.695939  09/11/2020    9     11  2020     80       3
# 7           3.656508  08/11/2020    8     11  2020    126       6
# 8           3.538217  07/11/2020    7     11  2020     58       2
# 9           3.546103  06/11/2020    6     11  2020     40       0
#
#   countriesAndTerritories
# 5             Afghanistan
# 6             Afghanistan
# 7             Afghanistan
# 8             Afghanistan
# 9             Afghanistan

# %%
df['Cumulative_number'].unique()
# Out:
# array([4.57129254, 4.23219148, 4.47140231, ..., 0.12290487, 0.10924878,
#        0.04779634])

# %%
df['Cumulative_number'] = df.sum(axis=1)

# %%
df.groupby('Cumulative_number').sum()
# Out:
#                    day  month   year  cases  deaths   popData2019
# Cumulative_number
# 2.842000e+03         1      6   2020      0       0  8.150000e+02
# 2.843000e+03         3     13   4040      0       0  1.630000e+03
# 2.844000e+03         6     21   6060      0       0  2.445000e+03
# 2.845000e+03        10     30   8080      0       0  3.260000e+03
# 2.846000e+03        15     40  10100      0       0  4.075000e+03
# ...                ...    ...    ...    ...     ...           ...
# 1.433789e+09         8      2   2020   3418      86  1.433784e+09
# 1.433790e+09         6      2   2020   3727      72  1.433784e+09
# 1.433790e+09         5      2   2020   3872      66  1.433784e+09
# 1.433790e+09        14      2   2020   4156      13  1.433784e+09
# 1.433801e+09        13      2   2020  15141     254  1.433784e+09
#
# [47863 rows x 6 columns]

# %%
is_2020 =  df['year']==2020

# %%
 df.sort_values('Cumulative_number',ascending=True)
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 22009       2.842000e+03  01/06/2020    1      6  2020      0       0
# 22008       2.843000e+03  02/06/2020    2      6  2020      0       0
# 21979       2.843000e+03  01/07/2020    1      7  2020      0       0
# 21978       2.844000e+03  02/07/2020    2      7  2020      0       0
# 21948       2.844000e+03  01/08/2020    1      8  2020      0       0
# ...                  ...         ...  ...    ...   ...    ...     ...
# 10593       1.433789e+09  08/02/2020    8      2  2020   3418      86
# 10595       1.433790e+09  06/02/2020    6      2  2020   3727      72
# 10596       1.433790e+09  05/02/2020    5      2  2020   3872      66
# 10587       1.433790e+09  14/02/2020   14      2  2020   4156      13
# 10588       1.433801e+09  13/02/2020   13      2  2020  15141     254
#
#       countriesAndTerritories geoId countryterritoryCode   popData2019  \
# ...

# %%
df.sort_values(['Cumulative_number','dateRep'])
# Out:
#        Cumulative_number     dateRep  day  month  year  cases  deaths  \
# 22009       2.842000e+03  01/06/2020    1      6  2020      0       0
# 21979       2.843000e+03  01/07/2020    1      7  2020      0       0
# 22008       2.843000e+03  02/06/2020    2      6  2020      0       0
# 21948       2.844000e+03  01/08/2020    1      8  2020      0       0
# 21978       2.844000e+03  02/07/2020    2      7  2020      0       0
# ...                  ...         ...  ...    ...   ...    ...     ...
# 10593       1.433789e+09  08/02/2020    8      2  2020   3418      86
# 10595       1.433790e+09  06/02/2020    6      2  2020   3727      72
# 10596       1.433790e+09  05/02/2020    5      2  2020   3872      66
# 10587       1.433790e+09  14/02/2020   14      2  2020   4156      13
# 10588       1.433801e+09  13/02/2020   13      2  2020  15141     254
#
#       countriesAndTerritories geoId countryterritoryCode   popData2019  \
# ...

# %%
df['new_col'] = range(len(df))

# %%
newDf = df.append(df)

# %%
writer =pd.ExcelWriter('COVID-19-geographic-disbtribution-worldwide.xlsx')
df.to_excel(writer,'Sheet_1')
writer.save()

# %%
df['Cumulative_number'].plot.line()
